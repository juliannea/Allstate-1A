# %% [markdown]
# # **ALL STATE PROJECT(Predicting Auto Claims Severity)**![allstate-insurance-1.svg](data:image/svg+xml;base64,...)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("claims_data.csv")

# %%
print(df.shape)
df.head(1000)
# Out:
# (188318, 132)
#        id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6  \
# 0       1    A    B    A    B    A    A    A    A    B  ...  0.718367
# 1       2    A    B    A    A    A    A    A    A    B  ...  0.438917
# 2       5    A    B    A    A    B    A    A    A    B  ...  0.289648
# 3      10    B    B    A    B    A    A    A    A    B  ...  0.440945
# 4      11    A    B    A    B    A    A    A    A    B  ...  0.178193
# ..    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 995  3252    A    A    A    A    A    B    A    A    A  ...  0.426216
# 996  3253    A    A    A    B    A    A    A    A    A  ...  0.876738
# 997  3255    A    A    A    A    B    A    A    A    A  ...  0.531477
# 998  3256    A    B    A    A    B    A    A    A    B  ...  0.326207
# 999  3257    B    A    A    A    A    B    A    A    A  ...  0.317735
#
#         cont7    cont8    cont9   cont10    cont11    cont12    cont13  \
# 0    0.335060  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493
# 1    0.436585  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431
# 2    0.315545  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709
# 3    0.391128  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077
# 4    0.247408  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011
# ..        ...      ...      ...      ...       ...       ...       ...
# 995  0.692781  0.26847  0.38448  0.38541  0.341813  0.335036  0.312885
# 996  0.607870  0.97189  0.93383  0.83814  0.821840  0.832658  0.808455
# 997  0.465906  0.67787  0.79047  0.60932  0.592525  0.579845  0.723122
# 998  0.365369  0.36083  0.39849  0.39599  0.297750  0.292356  0.339244
# 999  0.392775  0.25918  0.35897  0.42828  0.327915  0.321570  0.276878
#
#        cont14     loss
# 0    0.714843  2213.18
# 1    0.304496  1283.60
# 2    0.774425  3005.09
# 3    0.602642   939.85
# 4    0.432606  2763.85
# ..        ...      ...
# 995  0.766488  1160.76
# 996  0.363641  1350.46
# 997  0.721395  1760.30
# 998  0.220647  3143.48
# 999  0.283699   726.22
#
# [1000 rows x 132 columns]

# %%
nan_count = df.isnull().sum()

nan_count[nan_count > 0]
# Out:
# Series([], dtype: int64)

# %%
df.shape
# Out:
# (188318, 132)

# %%
df.dtypes
# Out:
# id          int64
# cat1       object
# cat2       object
# cat3       object
# cat4       object
#            ...
# cont11    float64
# cont12    float64
# cont13    float64
# cont14    float64
# loss      float64
# Length: 132, dtype: object

# %%
df.describe()
# Out:
#                   id          cont1          cont2          cont3  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean   294135.982561       0.493861       0.507188       0.498918
# std    169336.084867       0.187640       0.207202       0.202105
# min         1.000000       0.000016       0.001149       0.002634
# 25%    147748.250000       0.346090       0.358319       0.336963
# 50%    294539.500000       0.475784       0.555782       0.527991
# 75%    440680.500000       0.623912       0.681761       0.634224
# max    587633.000000       0.984975       0.862654       0.944251
#
#                cont4          cont5          cont6          cont7  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.491812       0.487428       0.490945       0.484970
# std         0.211292       0.209027       0.205273       0.178450
# min         0.176921       0.281143       0.012683       0.069503
# 25%         0.327354       0.281143       0.336105       0.350175
# 50%         0.452887       0.422268       0.440945       0.438285
# 75%         0.652072       0.643315       0.655021       0.591045
# max         0.954297       0.983674       0.997162       1.000000
#
#                cont8          cont9         cont10         cont11  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.486437       0.485506       0.498066       0.493511
# std         0.199370       0.181660       0.185877       0.209737
# min         0.236880       0.000080       0.000000       0.035321
# 25%         0.312800       0.358970       0.364580       0.310961
# 50%         0.441060       0.441450       0.461190       0.457203
# 75%         0.623580       0.566820       0.614590       0.678924
# max         0.980200       0.995400       0.994980       0.998742
#
#               cont12         cont13         cont14           loss
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.493150       0.493138       0.495717    3037.337686
# std         0.209427       0.212777       0.222488    2904.086186
# min         0.036232       0.000228       0.179722       0.670000
# 25%         0.311661       0.315758       0.294610    1204.460000
# 50%         0.462286       0.363547       0.407403    2115.570000
# 75%         0.675759       0.689974       0.724623    3864.045000
# max         0.998484       0.988494       0.844848  121012.250000

# %%
df.nunique()
# Out:
# id        188318
# cat1           2
# cat2           2
# cat3           2
# cat4           2
#            ...
# cont11       326
# cont12       328
# cont13       353
# cont14     18740
# loss      158223
# Length: 132, dtype: int64

# %% [markdown]
# Look for any garbage fields,
#
# look at correlation between the features with the target
#
# plot the features against the target

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['loss'], bins=50, kde=True)
plt.title('Distribution of Loss')
plt.show()

# %%
continuous_features = ['cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13', 'cont14']
correlation_matrix = df[continuous_features + ['loss']].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Continuous Features and Loss')
plt.show()

# %% [markdown]
# # Task
# Perform additional EDA and data preprocessing steps on the dataset.

# %% [markdown]
# ## Categorical feature analysis
#
# ### Subtask:
# Analyze the categorical features to understand their unique values and distributions.

# %% [markdown]
# **Reasoning**:
# Identify and analyze the categorical features by printing the number of unique values and value counts for those with few unique values.

# %%
categorical_features = df.select_dtypes(include='object').columns

print("Number of unique values for each categorical feature:")
for col in categorical_features:
    unique_count = df[col].nunique()
    print(f"{col}: {unique_count}")
    if unique_count < 50:
        print(f"Value counts for {col}:")
        print(df[col].value_counts())
        print("-" * 20)
# Out:
# Number of unique values for each categorical feature:
# cat1: 2
# Value counts for cat1:
# cat1
# A    141550
# B     46768
# Name: count, dtype: int64
# --------------------
# cat2: 2
# Value counts for cat2:
# cat2
# A    106721
# B     81597
# Name: count, dtype: int64
# --------------------
# cat3: 2
# Value counts for cat3:
# cat3
# A    177993
# B     10325
# Name: count, dtype: int64
# --------------------
# cat4: 2
# Value counts for cat4:
# cat4
# A    128395
# B     59923
# Name: count, dtype: int64
# --------------------
# cat5: 2
# Value counts for cat5:
# cat5
# A    123737
# B     64581
# Name: count, dtype: int64
# --------------------
# cat6: 2
# Value counts for cat6:
# cat6
# A    131693
# B     56625
# Name: count, dtype: int64
# --------------------
# cat7: 2
# Value counts for cat7:
# cat7
# A    183744
# B      4574
# Name: count, dtype: int64
# --------------------
# cat8: 2
# Value counts for cat8:
# cat8
# A    177274
# B     11044
# Name: count, dtype: int64
# --------------------
# cat9: 2
# Value counts for cat9:
# cat9
# A    113122
# B     75196
# Name: count, dtype: int64
# --------------------
# cat10: 2
# Value counts for cat10:
# cat10
# A    160213
# B     28105
# Name: count, dtype: int64
# --------------------
# cat11: 2
# Value counts for cat11:
# cat11
# A    168186
# B     20132
# Name: count, dtype: int64
# --------------------
# cat12: 2
# Value counts for cat12:
# cat12
# A    159825
# B     28493
# Name: count, dtype: int64
# --------------------
# cat13: 2
# Value counts for cat13:
# cat13
# A    168851
# B     19467
# Name: count, dtype: int64
# --------------------
# cat14: 2
# Value counts for cat14:
# cat14
# A    186041
# B      2277
# Name: count, dtype: int64
# --------------------
# cat15: 2
# Value counts for cat15:
# cat15
# A    188284
# B        34
# Name: count, dtype: int64
# --------------------
# cat16: 2
# Value counts for cat16:
# cat16
# A    181843
# B      6475
# Name: count, dtype: int64
# --------------------
# cat17: 2
# Value counts for cat17:
# cat17
# A    187009
# B      1309
# Name: count, dtype: int64
# --------------------
# cat18: 2
# Value counts for cat18:
# cat18
# A    187331
# B       987
# Name: count, dtype: int64
# --------------------
# cat19: 2
# Value counts for cat19:
# cat19
# A    186510
# B      1808
# Name: count, dtype: int64
# --------------------
# cat20: 2
# Value counts for cat20:
# cat20
# A    188114
# B       204
# Name: count, dtype: int64
# --------------------
# cat21: 2
# Value counts for cat21:
# cat21
# A    187905
# B       413
# Name: count, dtype: int64
# --------------------
# cat22: 2
# Value counts for cat22:
# cat22
# A    188275
# B        43
# Name: count, dtype: int64
# --------------------
# cat23: 2
# Value counts for cat23:
# cat23
# A    157445
# B     30873
# Name: count, dtype: int64
# --------------------
# cat24: 2
# Value counts for cat24:
# cat24
# A    181977
# B      6341
# Name: count, dtype: int64
# --------------------
# cat25: 2
# Value counts for cat25:
# cat25
# A    169969
# B     18349
# Name: count, dtype: int64
# --------------------
# cat26: 2
# Value counts for cat26:
# cat26
# A    177119
# B     11199
# Name: count, dtype: int64
# --------------------
# cat27: 2
# Value counts for cat27:
# cat27
# A    168250
# B     20068
# Name: count, dtype: int64
# --------------------
# cat28: 2
# Value counts for cat28:
# cat28
# A    180938
# B      7380
# Name: count, dtype: int64
# --------------------
# cat29: 2
# Value counts for cat29:
# cat29
# A    184593
# B      3725
# Name: count, dtype: int64
# --------------------
# cat30: 2
# Value counts for cat30:
# cat30
# A    184760
# B      3558
# Name: count, dtype: int64
# --------------------
# cat31: 2
# Value counts for cat31:
# cat31
# A    182980
# B      5338
# Name: count, dtype: int64
# --------------------
# cat32: 2
# Value counts for cat32:
# cat32
# A    187107
# B      1211
# Name: count, dtype: int64
# --------------------
# cat33: 2
# Value counts for cat33:
# cat33
# A    187361
# B       957
# Name: count, dtype: int64
# --------------------
# cat34: 2
# Value counts for cat34:
# cat34
# A    187734
# B       584
# Name: count, dtype: int64
# --------------------
# cat35: 2
# Value counts for cat35:
# cat35
# A    188105
# B       213
# Name: count, dtype: int64
# --------------------
# cat36: 2
# Value counts for cat36:
# cat36
# A    156313
# B     32005
# Name: count, dtype: int64
# --------------------
# cat37: 2
# Value counts for cat37:
# cat37
# A    165729
# B     22589
# Name: count, dtype: int64
# --------------------
# cat38: 2
# Value counts for cat38:
# cat38
# A    169323
# B     18995
# Name: count, dtype: int64
# --------------------
# cat39: 2
# Value counts for cat39:
# cat39
# A    183393
# B      4925
# Name: count, dtype: int64
# --------------------
# cat40: 2
# Value counts for cat40:
# cat40
# A    180119
# B      8199
# Name: count, dtype: int64
# --------------------
# cat41: 2
# Value counts for cat41:
# cat41
# A    181177
# B      7141
# Name: count, dtype: int64
# --------------------
# cat42: 2
# Value counts for cat42:
# cat42
# A    186623
# B      1695
# Name: count, dtype: int64
# --------------------
# cat43: 2
# Value counts for cat43:
# cat43
# A    184110
# B      4208
# Name: count, dtype: int64
# --------------------
# cat44: 2
# Value counts for cat44:
# cat44
# A    172716
# B     15602
# Name: count, dtype: int64
# --------------------
# cat45: 2
# Value counts for cat45:
# cat45
# A    183991
# B      4327
# Name: count, dtype: int64
# --------------------
# cat46: 2
# Value counts for cat46:
# cat46
# A    187436
# B       882
# Name: count, dtype: int64
# --------------------
# cat47: 2
# Value counts for cat47:
# cat47
# A    187617
# B       701
# Name: count, dtype: int64
# --------------------
# cat48: 2
# Value counts for cat48:
# cat48
# A    188049
# B       269
# Name: count, dtype: int64
# --------------------
# cat49: 2
# Value counts for cat49:
# cat49
# A    179127
# B      9191
# Name: count, dtype: int64
# --------------------
# cat50: 2
# Value counts for cat50:
# cat50
# A    137611
# B     50707
# Name: count, dtype: int64
# --------------------
# cat51: 2
# Value counts for cat51:
# cat51
# A    187071
# B      1247
# Name: count, dtype: int64
# --------------------
# cat52: 2
# Value counts for cat52:
# cat52
# A    179505
# B      8813
# Name: count, dtype: int64
# --------------------
# cat53: 2
# Value counts for cat53:
# cat53
# A    172949
# B     15369
# Name: count, dtype: int64
# --------------------
# cat54: 2
# Value counts for cat54:
# cat54
# A    183762
# B      4556
# Name: count, dtype: int64
# --------------------
# cat55: 2
# Value counts for cat55:
# cat55
# A    188173
# B       145
# Name: count, dtype: int64
# --------------------
# cat56: 2
# Value counts for cat56:
# cat56
# A    188136
# B       182
# Name: count, dtype: int64
# --------------------
# cat57: 2
# Value counts for cat57:
# cat57
# A    185296
# B      3022
# Name: count, dtype: int64
# --------------------
# cat58: 2
# Value counts for cat58:
# cat58
# A    188079
# B       239
# Name: count, dtype: int64
# --------------------
# cat59: 2
# Value counts for cat59:
# cat59
# A    188018
# B       300
# Name: count, dtype: int64
# --------------------
# cat60: 2
# Value counts for cat60:
# cat60
# A    187872
# B       446
# Name: count, dtype: int64
# --------------------
# cat61: 2
# Value counts for cat61:
# cat61
# A    187596
# B       722
# Name: count, dtype: int64
# --------------------
# cat62: 2
# Value counts for cat62:
# cat62
# A    188273
# B        45
# Name: count, dtype: int64
# --------------------
# cat63: 2
# Value counts for cat63:
# cat63
# A    188239
# B        79
# Name: count, dtype: int64
# --------------------
# cat64: 2
# Value counts for cat64:
# cat64
# A    188271
# B        47
# Name: count, dtype: int64
# --------------------
# cat65: 2
# Value counts for cat65:
# cat65
# A    186056
# B      2262
# Name: count, dtype: int64
# --------------------
# cat66: 2
# Value counts for cat66:
# cat66
# A    179982
# B      8336
# Name: count, dtype: int64
# --------------------
# cat67: 2
# Value counts for cat67:
# cat67
# A    187626
# B       692
# Name: count, dtype: int64
# --------------------
# cat68: 2
# Value counts for cat68:
# cat68
# A    188176
# B       142
# Name: count, dtype: int64
# --------------------
# cat69: 2
# Value counts for cat69:
# cat69
# A    188011
# B       307
# Name: count, dtype: int64
# --------------------
# cat70: 2
# Value counts for cat70:
# cat70
# A    188295
# B        23
# Name: count, dtype: int64
# --------------------
# cat71: 2
# Value counts for cat71:
# cat71
# A    178646
# B      9672
# Name: count, dtype: int64
# --------------------
# cat72: 2
# Value counts for cat72:
# cat72
# A    118322
# B     69996
# Name: count, dtype: int64
# --------------------
# cat73: 3
# Value counts for cat73:
# cat73
# A    154275
# B     34017
# C        26
# Name: count, dtype: int64
# --------------------
# cat74: 3
# Value counts for cat74:
# cat74
# A    184731
# B      3561
# C        26
# Name: count, dtype: int64
# --------------------
# cat75: 3
# Value counts for cat75:
# cat75
# A    154307
# B     34010
# C         1
# Name: count, dtype: int64
# --------------------
# cat76: 3
# Value counts for cat76:
# cat76
# A    181347
# B      6183
# C       788
# Name: count, dtype: int64
# --------------------
# cat77: 4
# Value counts for cat77:
# cat77
# D    187503
# C       408
# B       358
# A        49
# Name: count, dtype: int64
# --------------------
# cat78: 4
# Value counts for cat78:
# cat78
# B    186526
# A       788
# C       645
# D       359
# Name: count, dtype: int64
# --------------------
# cat79: 4
# Value counts for cat79:
# cat79
# B    152929
# D     26657
# A      7064
# C      1668
# Name: count, dtype: int64
# --------------------
# cat80: 4
# Value counts for cat80:
# cat80
# D    137505
# B     46538
# C      3492
# A       783
# Name: count, dtype: int64
# --------------------
# cat81: 4
# Value counts for cat81:
# cat81
# D    154385
# B     24132
# C      9013
# A       788
# Name: count, dtype: int64
# --------------------
# cat82: 4
# Value counts for cat82:
# cat82
# B    147536
# A     19322
# D     18805
# C      2655
# Name: count, dtype: int64
# --------------------
# cat83: 4
# Value counts for cat83:
# cat83
# B    141534
# A     26038
# D     15788
# C      4958
# Name: count, dtype: int64
# --------------------
# cat84: 4
# Value counts for cat84:
# cat84
# C    154939
# A     29450
# D      3498
# B       431
# Name: count, dtype: int64
# --------------------
# cat85: 4
# Value counts for cat85:
# cat85
# B    186005
# C      1011
# A       788
# D       514
# Name: count, dtype: int64
# --------------------
# cat86: 4
# Value counts for cat86:
# cat86
# B    103852
# D     72587
# C     10290
# A      1589
# Name: count, dtype: int64
# --------------------
# cat87: 4
# Value counts for cat87:
# cat87
# B    166992
# D     11719
# C      8819
# A       788
# Name: count, dtype: int64
# --------------------
# cat88: 4
# Value counts for cat88:
# cat88
# A    168926
# D     19302
# E        83
# B         7
# Name: count, dtype: int64
# --------------------
# cat89: 8
# Value counts for cat89:
# cat89
# A    183744
# B      4312
# C       220
# D        33
# E         5
# I         2
# H         1
# G         1
# Name: count, dtype: int64
# --------------------
# cat90: 7
# Value counts for cat90:
# cat90
# A    177993
# B      9515
# C       728
# D        70
# E         6
# F         4
# G         2
# Name: count, dtype: int64
# --------------------
# cat91: 8
# Value counts for cat91:
# cat91
# A    111028
# B     42630
# G     26734
# C      6400
# D      1149
# E       254
# F        97
# H        26
# Name: count, dtype: int64
# --------------------
# cat92: 7
# Value counts for cat92:
# cat92
# A    124689
# H     62901
# B       628
# C        62
# I        26
# D        11
# F         1
# Name: count, dtype: int64
# --------------------
# cat93: 5
# Value counts for cat93:
# cat93
# D    150237
# C     35788
# B      1133
# E       728
# A       432
# Name: count, dtype: int64
# --------------------
# cat94: 7
# Value counts for cat94:
# cat94
# D    121642
# B     51710
# C     13623
# A       738
# F       494
# E        91
# G        20
# Name: count, dtype: int64
# --------------------
# cat95: 5
# Value counts for cat95:
# cat95
# C    87531
# D    79525
# E    17417
# A     3736
# B      109
# Name: count, dtype: int64
# --------------------
# cat96: 8
# Value counts for cat96:
# cat96
# E    174360
# D      7922
# B      2957
# G      2665
# F       343
# A        35
# C        24
# I        12
# Name: count, dtype: int64
# --------------------
# cat97: 7
# Value counts for cat97:
# cat97
# C    78127
# E    47450
# A    41970
# G    16745
# D     3779
# F      213
# B       34
# Name: count, dtype: int64
# --------------------
# cat98: 5
# Value counts for cat98:
# cat98
# A    105492
# D     50557
# C     21485
# E     10242
# B       542
# Name: count, dtype: int64
# --------------------
# cat99: 16
# Value counts for cat99:
# cat99
# P    79455
# T    72591
# R    10290
# D     8844
# S     7045
# N     2894
# K     2703
# F     2702
# E     1034
# C      310
# J      245
# H       93
# M       52
# I       38
# G       19
# O        3
# Name: count, dtype: int64
# --------------------
# cat100: 15
# Value counts for cat100:
# cat100
# F    42970
# I    39933
# L    19961
# K    13817
# G    12935
# J    12027
# H    10776
# A     9402
# N     7592
# B     6608
# O     5697
# M     5185
# C      836
# D      553
# E       26
# Name: count, dtype: int64
# --------------------
# cat101: 19
# Value counts for cat101:
# cat101
# A    106721
# D     17171
# C     16971
# G     10944
# F     10139
# J      7259
# I      6690
# M      3669
# L      3173
# Q      2762
# O      2493
# S       173
# R       138
# E         7
# B         3
# K         2
# N         1
# H         1
# U         1
# Name: count, dtype: int64
# --------------------
# cat102: 9
# Value counts for cat102:
# cat102
# A    177274
# B      5155
# C      4929
# E       482
# D       449
# G        15
# F        12
# H         1
# J         1
# Name: count, dtype: int64
# --------------------
# cat103: 13
# Value counts for cat103:
# cat103
# A    123737
# B     33342
# C     16508
# D      7806
# E      4473
# F      1528
# G       550
# H       190
# I       109
# J        45
# L        17
# K        11
# N         2
# Name: count, dtype: int64
# --------------------
# cat104: 17
# Value counts for cat104:
# cat104
# E    42925
# G    40660
# D    27611
# F    19228
# H    17187
# K    14297
# I    10919
# C     6949
# L     3486
# J     3138
# M     1156
# O      409
# N      153
# P       86
# A       68
# B       43
# Q        3
# Name: count, dtype: int64
# --------------------
# cat105: 20
# Value counts for cat105:
# cat105
# E    76493
# F    62892
# G    20613
# D    12172
# H    11258
# I     2941
# J      694
# K      486
# C      275
# M      171
# L      145
# A       77
# N       64
# P       15
# O        9
# B        5
# Q        4
# R        2
# T        1
# S        1
# Name: count, dtype: int64
# --------------------
# cat106: 17
# Value counts for cat106:
# cat106
# G    47165
# H    37713
# F    36143
# I    21433
# J    18281
# E    13000
# K     7958
# L     2971
# D     1934
# M     1176
# N      231
# C      129
# A       75
# O       66
# R       32
# B        9
# P        2
# Name: count, dtype: int64
# --------------------
# cat107: 20
# Value counts for cat107:
# cat107
# F    47310
# G    28560
# H    23461
# J    22405
# K    20236
# I    20066
# E    12521
# L     6976
# D     3225
# M     2067
# N      797
# C      213
# Q      140
# O      125
# P      100
# A       75
# U       32
# R        5
# B        2
# S        2
# Name: count, dtype: int64
# --------------------
# cat108: 11
# Value counts for cat108:
# cat108
# B    65512
# K    42435
# G    21421
# D    19160
# F    10242
# A     9299
# E     7968
# I     7243
# H     4305
# C      520
# J      213
# Name: count, dtype: int64
# --------------------
# cat109: 84
# cat110: 131
# cat111: 16
# Value counts for cat111:
# cat111
# A    128395
# C     32401
# E     14682
# G      7039
# I      3578
# K      1353
# M       473
# O       221
# Q        91
# S        38
# W        16
# U        16
# B         7
# F         3
# D         3
# Y         2
# Name: count, dtype: int64
# --------------------
# cat112: 51
# cat113: 61
# cat114: 19
# Value counts for cat114:
# cat114
# A    131693
# C     16793
# E     16475
# J      8199
# F      7905
# N      2455
# I      2432
# R       912
# L       870
# U       250
# O       240
# Q        43
# V        33
# B         6
# D         5
# S         4
# X         1
# W         1
# G         1
# Name: count, dtype: int64
# --------------------
# cat115: 23
# Value counts for cat115:
# cat115
# K    43866
# O    26813
# J    23895
# N    22438
# P    21538
# L    16125
# M    12444
# Q     8258
# I     7090
# H     2793
# R     2038
# G      315
# F      269
# S      250
# A       75
# T       56
# U       26
# E       11
# W        6
# X        5
# D        4
# B        2
# C        1
# Name: count, dtype: int64
# --------------------
# cat116: 326

# %% [markdown]
# **Reasoning**:
# Visualize the distribution of some of the categorical features with a small number of unique values using count plots.

# %%
categorical_features_to_plot = [col for col in categorical_features if df[col].nunique() < 10]

n_cols = 3
n_rows = (len(categorical_features_to_plot) + n_cols - 1) // n_cols

plt.figure(figsize=(15, n_rows * 4))
for i, col in enumerate(categorical_features_to_plot):
    plt.subplot(n_rows, n_cols, i + 1)
    sns.countplot(data=df, x=col, order=df[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical feature encoding
#
# ### Subtask:
# Encode categorical features using appropriate techniques like one-hot encoding.

# %% [markdown]
# **Reasoning**:
# Identify categorical columns and apply one-hot encoding, then concatenate with the original dataframe while dropping the original categorical columns.

# %%
categorical_cols = df.select_dtypes(include='object').columns

df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

display(df_encoded.head())
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   1  0.726300  0.245921  0.187583  0.789639  0.310061  0.718367  0.335060
# 1   2  0.330514  0.737068  0.592681  0.614134  0.885834  0.438917  0.436585
# 2   5  0.261841  0.358319  0.484196  0.236924  0.397069  0.289648  0.315545
# 3  10  0.321594  0.555782  0.527991  0.373816  0.422268  0.440945  0.391128
# 4  11  0.273204  0.159990  0.527991  0.473202  0.704268  0.178193  0.247408
#
#      cont8    cont9  ...  cat116_P  cat116_Q  cat116_R  cat116_S  cat116_T  \
# 0  0.30260  0.67135  ...     False     False     False     False     False
# 1  0.60087  0.35127  ...     False     False     False     False     False
# 2  0.27320  0.26076  ...     False     False     False     False     False
# 3  0.31796  0.32128  ...     False     False     False     False     False
# 4  0.24564  0.22089  ...     False     False     False     False     False
#
#    cat116_U  cat116_V  cat116_W  cat116_X  cat116_Y
# 0     False     False     False     False     False
# 1     False     False     False     False     False
# 2     False     False     False     False     False
# 3     False     False     False     False     False
# 4     False     False     False     False     False
#
# [5 rows x 1039 columns]

# %% [markdown]
# ## Feature scaling
#
# ### Subtask:
# Scale numerical features to ensure they have similar ranges.

# %% [markdown]
# **Reasoning**:
# Identify the numerical features, excluding 'loss' and 'id', and then scale them using StandardScaler.

# %%
numerical_features = df_encoded.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_features.remove('loss')
numerical_features.remove('id')

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_encoded[numerical_features] = scaler.fit_transform(df_encoded[numerical_features])

display(df_encoded.head())
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   1  1.238750 -1.260936 -1.540471  1.409553 -0.848538  1.107908 -0.840070
# 1   2 -0.870537  1.109451  0.463932  0.578923  1.906010 -0.253457 -0.271142
# 2   5 -1.236521 -0.718477 -0.072846 -1.206334 -0.432284 -0.980633 -0.949428
# 3  10 -0.918075  0.234524  0.143849 -0.558452 -0.311730 -0.243577 -0.525875
# 4  11 -1.175963 -1.675658  0.143849 -0.088079  1.037383 -1.523596 -1.331256
#
#       cont8     cont9  ...  cat116_P  cat116_Q  cat116_R  cat116_S  cat116_T  \
# 0 -0.922092  1.023032  ...     False     False     False     False     False
# 1  0.573972 -0.738944  ...     False     False     False     False     False
# 2 -1.069556 -1.237183  ...     False     False     False     False     False
# 3 -0.845049 -0.904033  ...     False     False     False     False     False
# 4 -1.207792 -1.456660  ...     False     False     False     False     False
#
#    cat116_U  cat116_V  cat116_W  cat116_X  cat116_Y
# 0     False     False     False     False     False
# 1     False     False     False     False     False
# 2     False     False     False     False     False
# 3     False     False     False     False     False
# 4     False     False     False     False     False
#
# [5 rows x 1039 columns]

# %% [markdown]
# ## Feature engineering
#
# ### Subtask:
# Explore potential feature engineering steps to create new features that might improve the model's performance.

# %% [markdown]
# **Reasoning**:
# Implement one or two promising feature engineering steps and add them to the df_encoded DataFrame. Display the head of the updated df_encoded DataFrame to inspect the newly created features.

# %%
# Example feature engineering: Create polynomial features for some continuous variables
# choose 'cont1' and 'cont2' and create a second-degree polynomial
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2, include_bias=False)
poly_features = poly.fit_transform(df[['cont1', 'cont2']])

# Create a DataFrame for the new polynomial features
poly_feature_names = poly.get_feature_names_out(['cont1', 'cont2'])
df_poly = pd.DataFrame(poly_features, columns=poly_feature_names, index=df.index)

# Drop the original 'cont1' and 'cont2' from the polynomial features dataframe to avoid redundancy after merging
df_poly = df_poly.drop(columns=['cont1', 'cont2'], errors='ignore')


# Example feature engineering: Create interaction features for some categorical variables
# choose 'cat1' and 'cat2'
# Convert boolean columns back to 0 and 1 for multiplication
df_encoded['cat1_B_int'] = df_encoded['cat1_B'].astype(int)
df_encoded['cat2_B_int'] = df_encoded['cat2_B'].astype(int)
df_encoded['cat1_cat2_interaction'] = df_encoded['cat1_B_int'] * df_encoded['cat2_B_int']

# Drop the intermediate integer columns
df_encoded = df_encoded.drop(columns=['cat1_B_int', 'cat2_B_int'])


# Merge the new features into df_encoded
# Ensure the indices align before merging
df_encoded = pd.concat([df_encoded, df_poly], axis=1)


# Display the head of the updated DataFrame
display(df_encoded.head())
# Out:
# /tmp/ipython-input-2699819451.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_encoded['cat1_B_int'] = df_encoded['cat1_B'].astype(int)
# /tmp/ipython-input-2699819451.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_encoded['cat2_B_int'] = df_encoded['cat2_B'].astype(int)
# /tmp/ipython-input-2699819451.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_encoded['cat1_cat2_interaction'] = df_encoded['cat1_B_int'] * df_encoded['cat2_B_int']
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   1  1.238750 -1.260936 -1.540471  1.409553 -0.848538  1.107908 -0.840070
# 1   2 -0.870537  1.109451  0.463932  0.578923  1.906010 -0.253457 -0.271142
# 2   5 -1.236521 -0.718477 -0.072846 -1.206334 -0.432284 -0.980633 -0.949428
# 3  10 -0.918075  0.234524  0.143849 -0.558452 -0.311730 -0.243577 -0.525875
# 4  11 -1.175963 -1.675658  0.143849 -0.088079  1.037383 -1.523596 -1.331256
#
#       cont8     cont9  ...  cat116_T  cat116_U  cat116_V  cat116_W  cat116_X  \
# 0 -0.922092  1.023032  ...     False     False     False     False     False
# 1  0.573972 -0.738944  ...     False     False     False     False     False
# 2 -1.069556 -1.237183  ...     False     False     False     False     False
# 3 -0.845049 -0.904033  ...     False     False     False     False     False
# 4 -1.207792 -1.456660  ...     False     False     False     False     False
#
#    cat116_Y  cat1_cat2_interaction   cont1^2  cont1 cont2   cont2^2
# 0     False                      0  0.527512     0.178612  0.060477
# 1     False                      0  0.109240     0.243611  0.543269
# 2     False                      0  0.068561     0.093823  0.128393
# 3     False                      1  0.103423     0.178736  0.308894
# 4     False                      0  0.074640     0.043710  0.025597
#
# [5 rows x 1043 columns]

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   A large number of categorical features have a small number of unique values, primarily two ('A' and 'B'), while a few have a much larger number (up to 326).
# *   One-hot encoding was successfully applied to the categorical features, resulting in a significant increase in the number of columns in the dataset.
# *   Numerical features (excluding 'loss' and 'id') were successfully scaled using `StandardScaler`, resulting in values centered around zero with a standard deviation of one.
# *   New features were engineered by creating second-degree polynomial terms for 'cont1' and 'cont2' and an interaction term between 'cat1\_B' and 'cat2\_B', which were then added to the dataset.
#
# ### Insights or Next Steps
#
# *   Consider investigating the categorical features with a large number of unique values further to determine if alternative encoding methods (e.g., target encoding, frequency encoding) would be more appropriate.
# *   Evaluate the impact of the engineered polynomial and interaction features on model performance in subsequent modeling steps.
